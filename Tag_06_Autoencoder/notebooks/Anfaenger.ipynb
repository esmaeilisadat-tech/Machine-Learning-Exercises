# %% [markdown]
# ## Exercise 1: Simple Autoencoder in Keras
# **Dataset Used:** MNIST (keras.datasets)
#
# 1. Load MNIST, normalize to [0,1]. Build: Input(784)->Dense(128)->Dense(32)->Dense(128)->Dense(784).
# 2. Train with binary_crossentropy + adam for 10 epochs. Plot loss.
# 3. Visualize 10 original and reconstructed images.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input

# 1. Load and Normalize
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Build Autoencoder
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(32, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 2. Train
history = autoencoder.fit(x_train, x_train,
                epochs=10,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=1)

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Autoencoder Loss')
plt.legend()
plt.show()

# 3. Visualize
decoded_imgs = autoencoder.predict(x_test)
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
    # Reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 3:35 922ms/step - loss: 0.6937
#  11/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6756
#  23/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6200
#  38/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5563
#  53/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5112
#  68/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4780
#  83/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4522
#  99/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4300
# 116/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4106
# 131/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3960
# 147/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3825
# 162/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3714
# 177/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3615
# 193/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3520
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3439
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3360
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2278 - val_loss: 0.1491
# Epoch 2/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.1540
#  17/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1521
#  31/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1508
#  46/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1499
#  61/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491
#  75/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484
#  90/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477
# 104/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1471
# 118/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1465
# 132/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1458
# 146/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1453
# 161/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1446
# 176/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1440
# 193/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1434
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1428
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1423
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1337 - val_loss: 0.1193
# Epoch 3/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1271
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1225
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1216
#  43/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1212
#  58/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1207
#  73/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1204
#  87/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1201
# 103/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1197
# 118/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1195
# 134/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1192
# 149/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1190
# 164/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1187
# 179/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1185
# 193/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1183
# 206/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1181
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1180
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1146 - val_loss: 0.1079
# Epoch 4/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 0.1135
#  16/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1105
#  32/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1100
#  47/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1098
#  62/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1095
#  77/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1093
#  91/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1091
# 106/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1090
# 121/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1088
# 136/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1087
# 151/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1085
# 167/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1084
# 182/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1083
# 196/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1082
# 209/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1081
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1080
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1063 - val_loss: 0.1020
# Epoch 5/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0989
#  14/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1016
#  28/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1022
#  42/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1024
#  55/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
#  70/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
#  85/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026
#  99/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026
# 113/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026
# 127/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026
# 142/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026
# 158/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
# 171/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
# 188/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1025
# 203/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1024
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1024
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1024
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1017 - val_loss: 0.0986
# Epoch 6/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0997
#  13/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0993
#  28/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995
#  43/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995
#  57/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995
#  73/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995
#  87/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995
# 101/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 116/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 130/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 145/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 160/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 177/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 191/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# 207/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0993
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0993
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0993
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0988 - val_loss: 0.0967
# Epoch 7/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.1011
#  14/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0989
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0984
#  43/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0981
#  56/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0979
#  70/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0978
#  85/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0977
#  98/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0977
# 113/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0976
# 128/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0976
# 143/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0975
# 158/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0975
# 173/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0975
# 189/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0974
# 204/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0974
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0974
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0974
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0969 - val_loss: 0.0949
# Epoch 8/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.1007
#  13/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
#  26/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0961
#  40/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0960
#  54/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0958
#  70/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
#  85/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 101/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 115/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 130/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 145/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 160/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 175/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0957
# 190/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0956
# 205/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0956
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0956
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0954 - val_loss: 0.0943
# Epoch 9/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0919
#  16/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
#  31/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0945
#  46/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0945
#  62/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
#  76/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
#  91/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
# 105/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
# 119/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944
# 133/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 148/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 162/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 176/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 191/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 207/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0943
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0943 - val_loss: 0.0927
# Epoch 10/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0931
#  14/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0929
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0931
#  44/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932
#  59/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932
#  74/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932
#  89/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932
# 104/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932
# 119/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 134/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 149/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 163/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 177/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 193/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 209/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0933
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0933 - val_loss: 0.0919
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step
#  66/313 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 136/313 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step
# 198/313 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 266/313 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
