# %% [markdown]
# ## Exercise 1: Tuning, Blending and Deployment
# **Dataset Used:** Employee Attrition (PyCaret Built-in)
#
# 1. Select Top-3 models. Tune each with `tune_model`.
# 2. Blend the 3 tuned models with `blend_models()`.
# 3. Save best model and load it. Predict on new data.

# %%
# !pip install pycaret
from pycaret.classification import setup, compare_models, tune_model, blend_models, save_model, load_model, predict_model
from pycaret.datasets import get_data

# Load sample dataset
import pandas as pd
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=500, n_features=5, random_state=42)
data = pd.DataFrame(X, columns=['f1', 'f2', 'f3', 'f4', 'f5'])
data['Class variable'] = y
clf = setup(data=data, target='Class variable', session_id=123, verbose=False)

# 1. Top 3 models and Tuning
print("Finding top 3 models...")
top3 = compare_models(exclude=['catboost'], n_select=3, sort='AUC')

print("\nTuning top 3 models...")
# Reduced n_iter for speed in demonstration
tuned_top3 = [tune_model(m, n_iter=10, choose_better=True) for m in top3]

# 2. Blending
print("\nBlending models...")
blender = blend_models(estimator_list=tuned_top3)

# 3. Save, Load, Predict
print("\nSaving model...")
save_model(blender, 'blended_pipeline')

print("Loading model...")
loaded_model = load_model('blended_pipeline')

print("Predicting on new data (using a sample of original for demo)...")
predictions = predict_model(loaded_model, data=data.tail())
print(predictions[['left', 'prediction_label', 'prediction_score']])

print("\nREST API Deployment:")
print("To deploy this via REST API, you would use FastAPI or Flask. You load the model using `load_model()`, then expose an endpoint (e.g., POST /predict) that takes JSON data, converts it to a DataFrame, and calls `predict_model()`. PyCaret even has a built-in `create_api()` function for this!")
# Out:
# Finding top 3 models...
# <style type="text/css">
# #T_3c6f3 th {
#   text-align: left;
# }
# #T_3c6f3_row0_col0, #T_3c6f3_row0_col1, #T_3c6f3_row0_col3, #T_3c6f3_row0_col4, #T_3c6f3_row0_col5, #T_3c6f3_row0_col6, #T_3c6f3_row0_col7, #T_3c6f3_row1_col0, #T_3c6f3_row1_col1, #T_3c6f3_row1_col2, #T_3c6f3_row1_col3, #T_3c6f3_row1_col4, #T_3c6f3_row1_col5, #T_3c6f3_row1_col6, #T_3c6f3_row1_col7, #T_3c6f3_row2_col0, #T_3c6f3_row2_col1, #T_3c6f3_row2_col2, #T_3c6f3_row2_col3, #T_3c6f3_row2_col4, #T_3c6f3_row2_col5, #T_3c6f3_row2_col6, #T_3c6f3_row2_col7, #T_3c6f3_row3_col0, #T_3c6f3_row3_col1, #T_3c6f3_row3_col2, #T_3c6f3_row3_col3, #T_3c6f3_row3_col4, #T_3c6f3_row3_col5, #T_3c6f3_row3_col6, #T_3c6f3_row3_col7, #T_3c6f3_row4_col0, #T_3c6f3_row4_col2, #T_3c6f3_row4_col3, #T_3c6f3_row5_col0, #T_3c6f3_row5_col1, #T_3c6f3_row5_col2, #T_3c6f3_row5_col3, #T_3c6f3_row5_col4, #T_3c6f3_row5_col5, #T_3c6f3_row5_col6, #T_3c6f3_row5_col7, #T_3c6f3_row6_col0, #T_3c6f3_row6_col1, #T_3c6f3_row6_col2, #T_3c6f3_row6_col3, #T_3c6f3_row6_col4, #T_3c6f3_row6_col5, #T_3c6f3_row6_col6, #T_3c6f3_row6_col7, #T_3c6f3_row7_col0, #T_3c6f3_row7_col1, #T_3c6f3_row7_col2, #T_3c6f3_row7_col3, #T_3c6f3_row7_col4, #T_3c6f3_row7_col5, #T_3c6f3_row7_col6, #T_3c6f3_row7_col7, #T_3c6f3_row8_col0, #T_3c6f3_row8_col1, #T_3c6f3_row8_col2, #T_3c6f3_row8_col3, #T_3c6f3_row8_col4, #T_3c6f3_row8_col5, #T_3c6f3_row8_col6, #T_3c6f3_row8_col7, #T_3c6f3_row9_col0, #T_3c6f3_row9_col1, #T_3c6f3_row9_col2, #T_3c6f3_row9_col3, #T_3c6f3_row9_col4, #T_3c6f3_row9_col5, #T_3c6f3_row9_col6, #T_3c6f3_row9_col7, #T_3c6f3_row10_col0, #T_3c6f3_row10_col1, #T_3c6f3_row10_col2, #T_3c6f3_row10_col3, #T_3c6f3_row10_col4, #T_3c6f3_row10_col5, #T_3c6f3_row10_col6, #T_3c6f3_row10_col7, #T_3c6f3_row11_col0, #T_3c6f3_row11_col1, #T_3c6f3_row11_col2, #T_3c6f3_row11_col3, #T_3c6f3_row11_col4, #T_3c6f3_row11_col5, #T_3c6f3_row11_col6, #T_3c6f3_row11_col7, #T_3c6f3_row12_col0, #T_3c6f3_row12_col1, #T_3c6f3_row12_col2, #T_3c6f3_row12_col3, #T_3c6f3_row12_col4, #T_3c6f3_row12_col5, #T_3c6f3_row12_col6, #T_3c6f3_row12_col7, #T_3c6f3_row13_col0, #T_3c6f3_row13_col1, #T_3c6f3_row13_col2, #T_3c6f3_row13_col3, #T_3c6f3_row13_col4, #T_3c6f3_row13_col5, #T_3c6f3_row13_col6, #T_3c6f3_row13_col7, #T_3c6f3_row14_col0, #T_3c6f3_row14_col1, #T_3c6f3_row14_col2, #T_3c6f3_row14_col4, #T_3c6f3_row14_col5, #T_3c6f3_row14_col6, #T_3c6f3_row14_col7 {
#   text-align: left;
# }
# #T_3c6f3_row0_col2, #T_3c6f3_row4_col1, #T_3c6f3_row4_col4, #T_3c6f3_row4_col5, #T_3c6f3_row4_col6, #T_3c6f3_row4_col7, #T_3c6f3_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3c6f3_row0_col8, #T_3c6f3_row1_col8, #T_3c6f3_row2_col8, #T_3c6f3_row3_col8, #T_3c6f3_row4_col8, #T_3c6f3_row5_col8, #T_3c6f3_row6_col8, #T_3c6f3_row7_col8, #T_3c6f3_row9_col8, #T_3c6f3_row10_col8, #T_3c6f3_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3c6f3_row8_col8, #T_3c6f3_row11_col8, #T_3c6f3_row13_col8, #T_3c6f3_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3c6f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c6f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3c6f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3c6f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3c6f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3c6f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3c6f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3c6f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3c6f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3c6f3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c6f3_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_3c6f3_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_3c6f3_row0_col1" class="data row0 col1" >0.9343</td>
#       <td id="T_3c6f3_row0_col2" class="data row0 col2" >0.9837</td>
#       <td id="T_3c6f3_row0_col3" class="data row0 col3" >0.9320</td>
#       <td id="T_3c6f3_row0_col4" class="data row0 col4" >0.9388</td>
#       <td id="T_3c6f3_row0_col5" class="data row0 col5" >0.9346</td>
#       <td id="T_3c6f3_row0_col6" class="data row0 col6" >0.8686</td>
#       <td id="T_3c6f3_row0_col7" class="data row0 col7" >0.8701</td>
#       <td id="T_3c6f3_row0_col8" class="data row0 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_3c6f3_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_3c6f3_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_3c6f3_row1_col1" class="data row1 col1" >0.9343</td>
#       <td id="T_3c6f3_row1_col2" class="data row1 col2" >0.9827</td>
#       <td id="T_3c6f3_row1_col3" class="data row1 col3" >0.9261</td>
#       <td id="T_3c6f3_row1_col4" class="data row1 col4" >0.9427</td>
#       <td id="T_3c6f3_row1_col5" class="data row1 col5" >0.9334</td>
#       <td id="T_3c6f3_row1_col6" class="data row1 col6" >0.8686</td>
#       <td id="T_3c6f3_row1_col7" class="data row1 col7" >0.8704</td>
#       <td id="T_3c6f3_row1_col8" class="data row1 col8" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_3c6f3_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_3c6f3_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3c6f3_row2_col1" class="data row2 col1" >0.9343</td>
#       <td id="T_3c6f3_row2_col2" class="data row2 col2" >0.9814</td>
#       <td id="T_3c6f3_row2_col3" class="data row2 col3" >0.9320</td>
#       <td id="T_3c6f3_row2_col4" class="data row2 col4" >0.9381</td>
#       <td id="T_3c6f3_row2_col5" class="data row2 col5" >0.9341</td>
#       <td id="T_3c6f3_row2_col6" class="data row2 col6" >0.8686</td>
#       <td id="T_3c6f3_row2_col7" class="data row2 col7" >0.8704</td>
#       <td id="T_3c6f3_row2_col8" class="data row2 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_3c6f3_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_3c6f3_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3c6f3_row3_col1" class="data row3 col1" >0.9371</td>
#       <td id="T_3c6f3_row3_col2" class="data row3 col2" >0.9797</td>
#       <td id="T_3c6f3_row3_col3" class="data row3 col3" >0.9376</td>
#       <td id="T_3c6f3_row3_col4" class="data row3 col4" >0.9374</td>
#       <td id="T_3c6f3_row3_col5" class="data row3 col5" >0.9366</td>
#       <td id="T_3c6f3_row3_col6" class="data row3 col6" >0.8743</td>
#       <td id="T_3c6f3_row3_col7" class="data row3 col7" >0.8760</td>
#       <td id="T_3c6f3_row3_col8" class="data row3 col8" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_3c6f3_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_3c6f3_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3c6f3_row4_col1" class="data row4 col1" >0.9543</td>
#       <td id="T_3c6f3_row4_col2" class="data row4 col2" >0.9752</td>
#       <td id="T_3c6f3_row4_col3" class="data row4 col3" >0.9546</td>
#       <td id="T_3c6f3_row4_col4" class="data row4 col4" >0.9564</td>
#       <td id="T_3c6f3_row4_col5" class="data row4 col5" >0.9542</td>
#       <td id="T_3c6f3_row4_col6" class="data row4 col6" >0.9086</td>
#       <td id="T_3c6f3_row4_col7" class="data row4 col7" >0.9109</td>
#       <td id="T_3c6f3_row4_col8" class="data row4 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_3c6f3_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_3c6f3_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_3c6f3_row5_col1" class="data row5 col1" >0.9400</td>
#       <td id="T_3c6f3_row5_col2" class="data row5 col2" >0.9732</td>
#       <td id="T_3c6f3_row5_col3" class="data row5 col3" >0.9261</td>
#       <td id="T_3c6f3_row5_col4" class="data row5 col4" >0.9550</td>
#       <td id=
# Tuning top 3 models...
# <style type="text/css">
# #T_5ce1f_row10_col0, #T_5ce1f_row10_col1, #T_5ce1f_row10_col2, #T_5ce1f_row10_col3, #T_5ce1f_row10_col4, #T_5ce1f_row10_col5, #T_5ce1f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5ce1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ce1f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5ce1f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5ce1f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5ce1f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5ce1f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5ce1f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5ce1f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ce1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ce1f_row0_col0" class="data row0 col0" >0.8857</td>
#       <td id="T_5ce1f_row0_col1" class="data row0 col1" >0.9869</td>
#       <td id="T_5ce1f_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_5ce1f_row0_col3" class="data row0 col3" >0.8889</td>
#       <td id="T_5ce1f_row0_col4" class="data row0 col4" >0.8889</td>
#       <td id="T_5ce1f_row0_col5" class="data row0 col5" >0.7712</td>
#       <td id="T_5ce1f_row0_col6" class="data row0 col6" >0.7712</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ce1f_row1_col0" class="data row1 col0" >0.9429</td>
#       <td id="T_5ce1f_row1_col1" class="data row1 col1" >0.9902</td>
#       <td id="T_5ce1f_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_5ce1f_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_5ce1f_row1_col4" class="data row1 col4" >0.9412</td>
#       <td id="T_5ce1f_row1_col5" class="data row1 col5" >0.8860</td>
#       <td id="T_5ce1f_row1_col6" class="data row1 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ce1f_row2_col0" class="data row2 col0" >0.9714</td>
#       <td id="T_5ce1f_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_5ce1f_row2_col2" class="data row2 col2" >0.9444</td>
#       <td id="T_5ce1f_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_5ce1f_row2_col4" class="data row2 col4" >0.9714</td>
#       <td id="T_5ce1f_row2_col5" class="data row2 col5" >0.9429</td>
#       <td id="T_5ce1f_row2_col6" class="data row2 col6" >0.9444</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5ce1f_row3_col0" class="data row3 col0" >0.8857</td>
#       <td id="T_5ce1f_row3_col1" class="data row3 col1" >0.9771</td>
#       <td id="T_5ce1f_row3_col2" class="data row3 col2" >0.8333</td>
#       <td id="T_5ce1f_row3_col3" class="data row3 col3" >0.9375</td>
#       <td id="T_5ce1f_row3_col4" class="data row3 col4" >0.8824</td>
#       <td id="T_5ce1f_row3_col5" class="data row3 col5" >0.7720</td>
#       <td id="T_5ce1f_row3_col6" class="data row3 col6" >0.7771</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5ce1f_row4_col0" class="data row4 col0" >0.9143</td>
#       <td id="T_5ce1f_row4_col1" class="data row4 col1" >0.9837</td>
#       <td id="T_5ce1f_row4_col2" class="data row4 col2" >0.9444</td>
#       <td id="T_5ce1f_row4_col3" class="data row4 col3" >0.8947</td>
#       <td id="T_5ce1f_row4_col4" class="data row4 col4" >0.9189</td>
#       <td id="T_5ce1f_row4_col5" class="data row4 col5" >0.8282</td>
#       <td id="T_5ce1f_row4_col6" class="data row4 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5ce1f_row5_col0" class="data row5 col0" >0.9143</td>
#       <td id="T_5ce1f_row5_col1" class="data row5 col1" >0.9608</td>
#       <td id="T_5ce1f_row5_col2" class="data row5 col2" >0.8889</td>
#       <td id="T_5ce1f_row5_col3" class="data row5 col3" >0.9412</td>
#       <td id="T_5ce1f_row5_col4" class="data row5 col4" >0.9143</td>
#       <td id="T_5ce1f_row5_col5" class="data row5 col5" >0.8287</td>
#       <td id="T_5ce1f_row5_col6" class="data row5 col6" >0.8301</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5ce1f_row6_col0" class="data row6 col0" >0.8857</td>
#       <td id="T_5ce1f_row6_col1" class="data row6 col1" >0.9771</td>
#       <td id="T_5ce1f_row6_col2" class="data row6 col2" >0.8824</td>
#       <td id="T_5ce1f_row6_col3" class="data row6 col3" >0.8824</td>
#       <td id="T_5ce1f_row6_col4" class="data row6 col4" >0.8824</td>
#       <td id="T_5ce1f_row6_col5" class="data row6 col5" >0.7712</td>
#       <td id="T_5ce1f_row6_col6" class="data row6 col6" >0.7712</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ce1f_row7_col0" class="data row7 col0" >0.9714</td>
#       <td id="T_5ce1f_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_5ce1f_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_5ce1f_row7_col3" class="data row7 col3" >0.9444</td>
#       <td id="T_5ce1f_row7_col4" class="data row7 col4" >0.9714</td>
#       <td id="T_5ce1f_row7_col5" class="data row7 col5" >0.9429</td>
#       <td id="T_5ce1f_row7_col6" class="data row7 col6" >0.9444</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ce1f_row8_col0" class="data row8 col0" >0.9429</td>
#       <td id="T_5ce1f_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_5ce1f_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_5ce1f_row8_col3" class="data row8 col3" >0.8947</td>
#       <td id="T_5ce1f_row8_col4" class="data row8 col4" >0.9444</td>
#       <td id="T_5ce1f_row8_col5" class="data row8 col5" >0.8860</td>
#       <td id="T_5ce1f_row8_col6" class="data row8 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ce1f_row9_col0" class="data row9 col0" >0.8286</td>
#       <td id="T_5ce1f_row9_col1" class="data row9 col1" >0.9542</td>
#       <td id="T_5ce1f_row9_col2" class="data row9 col2" >0.8824</td>
#       <td id="T_5ce1f_row9_col3" class="data row9 col3" >0.7895</td>
#       <td id="T_5ce1f_row9_col4" class="data row9 col4" >0.8333</td>
#       <td id="T_5ce1f_row9_col5" class="data row9 col5" >0.6580</td>
#       <td id="T_5ce1f_row9_col6" class="data row9 col6" >0.6623</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5ce1f_row10_col0" class="data row10 col0" >0.9143</td>
#       <td id="T_5ce1f_row10_col1" class="data row10 col1" >0.9830</td>
#       <td id="T_5ce1f_row10_col2" class="data row10 col2" >0.9154</td>
#       <td id="T_5ce1f_row10_col3" class="data row10 col3" >0.9173</td>
#       <td id="T_5ce1f_row10_col4" class="data row10 col4" >0.9149</td>
#       <td id="T_5ce1f_row10_col5" class="data row10 col5" >0.8287</td>
#       <td id="T_5ce1f_row10_col6" class="data row10 col6" >0.8314</td>
#     </tr>
#     <tr>
#       <th id="T_5ce1f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5ce1f_row11_col0" class="data row11 col0" >0.0424</td>
#       <td id="T_5ce1f_row11_col1" class="data row11 col1" >0.0152</td>
#       <td id="T_5ce1f_row11_col2" class="data row11 col2" >0.0520</td>
#       <td id="T_5ce1f_row11_col3" class="data row11 col3" >0.0590</td>
#       <td id="T_5ce1f_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_030eb_row10_col0, #T_030eb_row10_col1, #T_030eb_row10_col2, #T_030eb_row10_col3, #T_030eb_row10_col4, #T_030eb_row10_col5, #T_030eb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_030eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_030eb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_030eb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_030eb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_030eb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_030eb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_030eb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_030eb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_030eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_030eb_row0_col0" class="data row0 col0" >0.9143</td>
#       <td id="T_030eb_row0_col1" class="data row0 col1" >0.9804</td>
#       <td id="T_030eb_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_030eb_row0_col3" class="data row0 col3" >0.9412</td>
#       <td id="T_030eb_row0_col4" class="data row0 col4" >0.9143</td>
#       <td id="T_030eb_row0_col5" class="data row0 col5" >0.8287</td>
#       <td id="T_030eb_row0_col6" class="data row0 col6" >0.8301</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_030eb_row1_col0" class="data row1 col0" >0.9143</td>
#       <td id="T_030eb_row1_col1" class="data row1 col1" >0.9869</td>
#       <td id="T_030eb_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_030eb_row1_col3" class="data row1 col3" >0.9412</td>
#       <td id="T_030eb_row1_col4" class="data row1 col4" >0.9143</td>
#       <td id="T_030eb_row1_col5" class="data row1 col5" >0.8287</td>
#       <td id="T_030eb_row1_col6" class="data row1 col6" >0.8301</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_030eb_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_030eb_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_030eb_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_030eb_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_030eb_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_030eb_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_030eb_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_030eb_row3_col0" class="data row3 col0" >0.9429</td>
#       <td id="T_030eb_row3_col1" class="data row3 col1" >0.9771</td>
#       <td id="T_030eb_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_030eb_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_030eb_row3_col4" class="data row3 col4" >0.9412</td>
#       <td id="T_030eb_row3_col5" class="data row3 col5" >0.8860</td>
#       <td id="T_030eb_row3_col6" class="data row3 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_030eb_row4_col0" class="data row4 col0" >0.9429</td>
#       <td id="T_030eb_row4_col1" class="data row4 col1" >0.9739</td>
#       <td id="T_030eb_row4_col2" class="data row4 col2" >0.9444</td>
#       <td id="T_030eb_row4_col3" class="data row4 col3" >0.9444</td>
#       <td id="T_030eb_row4_col4" class="data row4 col4" >0.9444</td>
#       <td id="T_030eb_row4_col5" class="data row4 col5" >0.8856</td>
#       <td id="T_030eb_row4_col6" class="data row4 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_030eb_row5_col0" class="data row5 col0" >0.9714</td>
#       <td id="T_030eb_row5_col1" class="data row5 col1" >0.9869</td>
#       <td id="T_030eb_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_030eb_row5_col3" class="data row5 col3" >0.9474</td>
#       <td id="T_030eb_row5_col4" class="data row5 col4" >0.9730</td>
#       <td id="T_030eb_row5_col5" class="data row5 col5" >0.9427</td>
#       <td id="T_030eb_row5_col6" class="data row5 col6" >0.9443</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_030eb_row6_col0" class="data row6 col0" >0.9143</td>
#       <td id="T_030eb_row6_col1" class="data row6 col1" >0.9739</td>
#       <td id="T_030eb_row6_col2" class="data row6 col2" >0.8824</td>
#       <td id="T_030eb_row6_col3" class="data row6 col3" >0.9375</td>
#       <td id="T_030eb_row6_col4" class="data row6 col4" >0.9091</td>
#       <td id="T_030eb_row6_col5" class="data row6 col5" >0.8282</td>
#       <td id="T_030eb_row6_col6" class="data row6 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_030eb_row7_col0" class="data row7 col0" >0.9714</td>
#       <td id="T_030eb_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_030eb_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_030eb_row7_col3" class="data row7 col3" >0.9444</td>
#       <td id="T_030eb_row7_col4" class="data row7 col4" >0.9714</td>
#       <td id="T_030eb_row7_col5" class="data row7 col5" >0.9429</td>
#       <td id="T_030eb_row7_col6" class="data row7 col6" >0.9444</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_030eb_row8_col0" class="data row8 col0" >0.9429</td>
#       <td id="T_030eb_row8_col1" class="data row8 col1" >0.9935</td>
#       <td id="T_030eb_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_030eb_row8_col3" class="data row8 col3" >0.8947</td>
#       <td id="T_030eb_row8_col4" class="data row8 col4" >0.9444</td>
#       <td id="T_030eb_row8_col5" class="data row8 col5" >0.8860</td>
#       <td id="T_030eb_row8_col6" class="data row8 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_030eb_row9_col0" class="data row9 col0" >0.8286</td>
#       <td id="T_030eb_row9_col1" class="data row9 col1" >0.9265</td>
#       <td id="T_030eb_row9_col2" class="data row9 col2" >0.8824</td>
#       <td id="T_030eb_row9_col3" class="data row9 col3" >0.7895</td>
#       <td id="T_030eb_row9_col4" class="data row9 col4" >0.8333</td>
#       <td id="T_030eb_row9_col5" class="data row9 col5" >0.6580</td>
#       <td id="T_030eb_row9_col6" class="data row9 col6" >0.6623</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_030eb_row10_col0" class="data row10 col0" >0.9343</td>
#       <td id="T_030eb_row10_col1" class="data row10 col1" >0.9799</td>
#       <td id="T_030eb_row10_col2" class="data row10 col2" >0.9376</td>
#       <td id="T_030eb_row10_col3" class="data row10 col3" >0.9340</td>
#       <td id="T_030eb_row10_col4" class="data row10 col4" >0.9345</td>
#       <td id="T_030eb_row10_col5" class="data row10 col5" >0.8687</td>
#       <td id="T_030eb_row10_col6" class="data row10 col6" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_030eb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_030eb_row11_col0" class="data row11 col0" >0.0444</td>
#       <td id="T_030eb_row11_col1" class="data row11 col1" >0.0201</td>
#       <td id="T_030eb_row11_col2" class="data row11 col2" >0.0537</td>
#       <td id="T_030eb_row11_col3" class="data row11 col3" >0.0563</td>
#       <td id="T_030eb_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_498a5_row10_col0, #T_498a5_row10_col1, #T_498a5_row10_col2, #T_498a5_row10_col3, #T_498a5_row10_col4, #T_498a5_row10_col5, #T_498a5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_498a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_498a5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_498a5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_498a5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_498a5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_498a5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_498a5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_498a5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_498a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_498a5_row0_col0" class="data row0 col0" >0.9429</td>
#       <td id="T_498a5_row0_col1" class="data row0 col1" >0.9902</td>
#       <td id="T_498a5_row0_col2" class="data row0 col2" >0.9444</td>
#       <td id="T_498a5_row0_col3" class="data row0 col3" >0.9444</td>
#       <td id="T_498a5_row0_col4" class="data row0 col4" >0.9444</td>
#       <td id="T_498a5_row0_col5" class="data row0 col5" >0.8856</td>
#       <td id="T_498a5_row0_col6" class="data row0 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_498a5_row1_col0" class="data row1 col0" >0.9143</td>
#       <td id="T_498a5_row1_col1" class="data row1 col1" >0.9673</td>
#       <td id="T_498a5_row1_col2" class="data row1 col2" >0.9444</td>
#       <td id="T_498a5_row1_col3" class="data row1 col3" >0.8947</td>
#       <td id="T_498a5_row1_col4" class="data row1 col4" >0.9189</td>
#       <td id="T_498a5_row1_col5" class="data row1 col5" >0.8282</td>
#       <td id="T_498a5_row1_col6" class="data row1 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_498a5_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_498a5_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_498a5_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_498a5_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_498a5_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_498a5_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_498a5_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_498a5_row3_col0" class="data row3 col0" >0.9429</td>
#       <td id="T_498a5_row3_col1" class="data row3 col1" >0.9379</td>
#       <td id="T_498a5_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_498a5_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_498a5_row3_col4" class="data row3 col4" >0.9412</td>
#       <td id="T_498a5_row3_col5" class="data row3 col5" >0.8860</td>
#       <td id="T_498a5_row3_col6" class="data row3 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_498a5_row4_col0" class="data row4 col0" >0.9429</td>
#       <td id="T_498a5_row4_col1" class="data row4 col1" >0.9837</td>
#       <td id="T_498a5_row4_col2" class="data row4 col2" >0.9444</td>
#       <td id="T_498a5_row4_col3" class="data row4 col3" >0.9444</td>
#       <td id="T_498a5_row4_col4" class="data row4 col4" >0.9444</td>
#       <td id="T_498a5_row4_col5" class="data row4 col5" >0.8856</td>
#       <td id="T_498a5_row4_col6" class="data row4 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_498a5_row5_col0" class="data row5 col0" >0.9143</td>
#       <td id="T_498a5_row5_col1" class="data row5 col1" >0.9739</td>
#       <td id="T_498a5_row5_col2" class="data row5 col2" >0.9444</td>
#       <td id="T_498a5_row5_col3" class="data row5 col3" >0.8947</td>
#       <td id="T_498a5_row5_col4" class="data row5 col4" >0.9189</td>
#       <td id="T_498a5_row5_col5" class="data row5 col5" >0.8282</td>
#       <td id="T_498a5_row5_col6" class="data row5 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_498a5_row6_col0" class="data row6 col0" >0.9429</td>
#       <td id="T_498a5_row6_col1" class="data row6 col1" >0.9869</td>
#       <td id="T_498a5_row6_col2" class="data row6 col2" >0.8824</td>
#       <td id="T_498a5_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_498a5_row6_col4" class="data row6 col4" >0.9375</td>
#       <td id="T_498a5_row6_col5" class="data row6 col5" >0.8852</td>
#       <td id="T_498a5_row6_col6" class="data row6 col6" >0.8911</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_498a5_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_498a5_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_498a5_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_498a5_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_498a5_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_498a5_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_498a5_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_498a5_row8_col0" class="data row8 col0" >0.9429</td>
#       <td id="T_498a5_row8_col1" class="data row8 col1" >0.9902</td>
#       <td id="T_498a5_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_498a5_row8_col3" class="data row8 col3" >0.8947</td>
#       <td id="T_498a5_row8_col4" class="data row8 col4" >0.9444</td>
#       <td id="T_498a5_row8_col5" class="data row8 col5" >0.8860</td>
#       <td id="T_498a5_row8_col6" class="data row8 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_498a5_row9_col0" class="data row9 col0" >0.9143</td>
#       <td id="T_498a5_row9_col1" class="data row9 col1" >0.9379</td>
#       <td id="T_498a5_row9_col2" class="data row9 col2" >0.9412</td>
#       <td id="T_498a5_row9_col3" class="data row9 col3" >0.8889</td>
#       <td id="T_498a5_row9_col4" class="data row9 col4" >0.9143</td>
#       <td id="T_498a5_row9_col5" class="data row9 col5" >0.8287</td>
#       <td id="T_498a5_row9_col6" class="data row9 col6" >0.8301</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_498a5_row10_col0" class="data row10 col0" >0.9457</td>
#       <td id="T_498a5_row10_col1" class="data row10 col1" >0.9768</td>
#       <td id="T_498a5_row10_col2" class="data row10 col2" >0.9490</td>
#       <td id="T_498a5_row10_col3" class="data row10 col3" >0.9462</td>
#       <td id="T_498a5_row10_col4" class="data row10 col4" >0.9464</td>
#       <td id="T_498a5_row10_col5" class="data row10 col5" >0.8913</td>
#       <td id="T_498a5_row10_col6" class="data row10 col6" >0.8935</td>
#     </tr>
#     <tr>
#       <th id="T_498a5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_498a5_row11_col0" class="data row11 col0" >0.0298</td>
#       <td id="T_498a5_row11_col1" class="data row11 col1" >0.0217</td>
#       <td id="T_498a5_row11_col2" class="data row11 col2" >0.0400</td>
#       <td id="T_498a5_row11_col3" class="data row11 col3" >0.0478</td>
#       <td id="T_498a5_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Blending models...
# <style type="text/css">
# #T_bc71a_row10_col0, #T_bc71a_row10_col1, #T_bc71a_row10_col2, #T_bc71a_row10_col3, #T_bc71a_row10_col4, #T_bc71a_row10_col5, #T_bc71a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bc71a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc71a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bc71a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bc71a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bc71a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bc71a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bc71a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bc71a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc71a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc71a_row0_col0" class="data row0 col0" >0.9429</td>
#       <td id="T_bc71a_row0_col1" class="data row0 col1" >0.9902</td>
#       <td id="T_bc71a_row0_col2" class="data row0 col2" >0.9444</td>
#       <td id="T_bc71a_row0_col3" class="data row0 col3" >0.9444</td>
#       <td id="T_bc71a_row0_col4" class="data row0 col4" >0.9444</td>
#       <td id="T_bc71a_row0_col5" class="data row0 col5" >0.8856</td>
#       <td id="T_bc71a_row0_col6" class="data row0 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc71a_row1_col0" class="data row1 col0" >0.9429</td>
#       <td id="T_bc71a_row1_col1" class="data row1 col1" >0.9902</td>
#       <td id="T_bc71a_row1_col2" class="data row1 col2" >0.9444</td>
#       <td id="T_bc71a_row1_col3" class="data row1 col3" >0.9444</td>
#       <td id="T_bc71a_row1_col4" class="data row1 col4" >0.9444</td>
#       <td id="T_bc71a_row1_col5" class="data row1 col5" >0.8856</td>
#       <td id="T_bc71a_row1_col6" class="data row1 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc71a_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_bc71a_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_bc71a_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_bc71a_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_bc71a_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_bc71a_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_bc71a_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc71a_row3_col0" class="data row3 col0" >0.9429</td>
#       <td id="T_bc71a_row3_col1" class="data row3 col1" >0.9739</td>
#       <td id="T_bc71a_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_bc71a_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_bc71a_row3_col4" class="data row3 col4" >0.9412</td>
#       <td id="T_bc71a_row3_col5" class="data row3 col5" >0.8860</td>
#       <td id="T_bc71a_row3_col6" class="data row3 col6" >0.8918</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc71a_row4_col0" class="data row4 col0" >0.9429</td>
#       <td id="T_bc71a_row4_col1" class="data row4 col1" >0.9902</td>
#       <td id="T_bc71a_row4_col2" class="data row4 col2" >0.9444</td>
#       <td id="T_bc71a_row4_col3" class="data row4 col3" >0.9444</td>
#       <td id="T_bc71a_row4_col4" class="data row4 col4" >0.9444</td>
#       <td id="T_bc71a_row4_col5" class="data row4 col5" >0.8856</td>
#       <td id="T_bc71a_row4_col6" class="data row4 col6" >0.8856</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc71a_row5_col0" class="data row5 col0" >0.9143</td>
#       <td id="T_bc71a_row5_col1" class="data row5 col1" >0.9837</td>
#       <td id="T_bc71a_row5_col2" class="data row5 col2" >0.9444</td>
#       <td id="T_bc71a_row5_col3" class="data row5 col3" >0.8947</td>
#       <td id="T_bc71a_row5_col4" class="data row5 col4" >0.9189</td>
#       <td id="T_bc71a_row5_col5" class="data row5 col5" >0.8282</td>
#       <td id="T_bc71a_row5_col6" class="data row5 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bc71a_row6_col0" class="data row6 col0" >0.9429</td>
#       <td id="T_bc71a_row6_col1" class="data row6 col1" >0.9935</td>
#       <td id="T_bc71a_row6_col2" class="data row6 col2" >0.8824</td>
#       <td id="T_bc71a_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_bc71a_row6_col4" class="data row6 col4" >0.9375</td>
#       <td id="T_bc71a_row6_col5" class="data row6 col5" >0.8852</td>
#       <td id="T_bc71a_row6_col6" class="data row6 col6" >0.8911</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bc71a_row7_col0" class="data row7 col0" >0.9714</td>
#       <td id="T_bc71a_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_bc71a_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_bc71a_row7_col3" class="data row7 col3" >0.9444</td>
#       <td id="T_bc71a_row7_col4" class="data row7 col4" >0.9714</td>
#       <td id="T_bc71a_row7_col5" class="data row7 col5" >0.9429</td>
#       <td id="T_bc71a_row7_col6" class="data row7 col6" >0.9444</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bc71a_row8_col0" class="data row8 col0" >0.9714</td>
#       <td id="T_bc71a_row8_col1" class="data row8 col1" >0.9967</td>
#       <td id="T_bc71a_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_bc71a_row8_col3" class="data row8 col3" >0.9444</td>
#       <td id="T_bc71a_row8_col4" class="data row8 col4" >0.9714</td>
#       <td id="T_bc71a_row8_col5" class="data row8 col5" >0.9429</td>
#       <td id="T_bc71a_row8_col6" class="data row8 col6" >0.9444</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bc71a_row9_col0" class="data row9 col0" >0.8857</td>
#       <td id="T_bc71a_row9_col1" class="data row9 col1" >0.9248</td>
#       <td id="T_bc71a_row9_col2" class="data row9 col2" >0.8824</td>
#       <td id="T_bc71a_row9_col3" class="data row9 col3" >0.8824</td>
#       <td id="T_bc71a_row9_col4" class="data row9 col4" >0.8824</td>
#       <td id="T_bc71a_row9_col5" class="data row9 col5" >0.7712</td>
#       <td id="T_bc71a_row9_col6" class="data row9 col6" >0.7712</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_bc71a_row10_col0" class="data row10 col0" >0.9457</td>
#       <td id="T_bc71a_row10_col1" class="data row10 col1" >0.9843</td>
#       <td id="T_bc71a_row10_col2" class="data row10 col2" >0.9431</td>
#       <td id="T_bc71a_row10_col3" class="data row10 col3" >0.9499</td>
#       <td id="T_bc71a_row10_col4" class="data row10 col4" >0.9456</td>
#       <td id="T_bc71a_row10_col5" class="data row10 col5" >0.8913</td>
#       <td id="T_bc71a_row10_col6" class="data row10 col6" >0.8929</td>
#     </tr>
#     <tr>
#       <th id="T_bc71a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_bc71a_row11_col0" class="data row11 col0" >0.0298</td>
#       <td id="T_bc71a_row11_col1" class="data row11 col1" >0.0212</td>
#       <td id="T_bc71a_row11_col2" class="data row11 col2" >0.0448</td>
#       <td id="T_bc71a_row11_col3" class="data row11 col3" >0.0391</td>
#       <td id="T_bc71a_row11_col4
# Saving model...
# Transformation Pipeline and Model Successfully Saved
# Loading model...
# Transformation Pipeline and Model Successfully Loaded
# Predicting on new data (using a sample of original for demo)...
# <style type="text/css">
# </style>
# <table id="T_17583">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17583_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17583_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_17583_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_17583_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_17583_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_17583_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_17583_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_17583_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17583_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17583_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_17583_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_17583_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_17583_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_17583_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_17583_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_17583_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_17583_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 34
#      30 loaded_model = load_model('blended_pipeline')
#      31
#      32 print("Predicting on new data (using a sample of original for demo)...")
#      33 predictions = predict_model(loaded_model, data=data.tail())
# ---> 34 print(predictions[['left', 'prediction_label', 'prediction_score']])
#      35
#      36 print("\nREST API Deployment:")
#      37 print("To deploy this via REST API, you would use FastAPI or Flask. You load the model using `load_model()`, then expose an endpoint (e.g., POST /predict) that takes JSON data, converts it to a DataFrame, and calls `predict_model()`. PyCaret even has a built-in `create_api()` function for this!")
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3895                 indexer = [indexer]
#    3896         else:
#    3897             if is_iterator(key):
#    3898                 key = list(key)
# -> 3899             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3900
#    3901         # take() does not accept boolean indexers
#    3902         if getattr(indexer, "dtype", None) == bool:
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pandas\core\indexes\base.py:6179, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['left'] not in index"
