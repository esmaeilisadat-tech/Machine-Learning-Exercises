# %% [markdown]
# ## Exercise 1: Tuning, Blending and Deployment
# **Dataset Used:** Employee Attrition (PyCaret Built-in)
#
# 1. Select Top-3 models. Tune each with `tune_model`.
# 2. Blend the 3 tuned models with `blend_models()`.
# 3. Save best model and load it. Predict on new data.

# %%
# # !pip install pycaret
from pycaret.classification import setup, compare_models, tune_model, blend_models, save_model, load_model, predict_model
from pycaret.datasets import get_data

# Load sample dataset
import pandas as pd
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=500, n_features=5, random_state=42)
data = pd.DataFrame(X, columns=['f1', 'f2', 'f3', 'f4', 'f5'])
data['Class variable'] = y
clf = setup(data=data, target='Class variable', session_id=123, verbose=False)

# 1. Top 3 models and Tuning
print("Finding top 3 models...")
top3 = compare_models(exclude=['catboost'], n_select=3, sort='AUC')

print("\nTuning top 3 models...")
# Reduced n_iter for speed in demonstration
tuned_top3 = [tune_model(m, n_iter=10, choose_better=True) for m in top3]

# 2. Blending
print("\nBlending models...")
blender = blend_models(estimator_list=tuned_top3)

# 3. Save, Load, Predict
print("\nSaving model...")
save_model(blender, 'blended_pipeline')

print("Loading model...")
loaded_model = load_model('blended_pipeline')

print("Predicting on new data (using a sample of original for demo)...")
predictions = predict_model(loaded_model, data=data.tail())
print(predictions[['left', 'prediction_label', 'prediction_score']])

print("\nREST API Deployment:")
print("To deploy this via REST API, you would use FastAPI or Flask. You load the model using `load_model()`, then expose an endpoint (e.g., POST /predict) that takes JSON data, converts it to a DataFrame, and calls `predict_model()`. PyCaret even has a built-in `create_api()` function for this!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 # # !pip install pycaret
# ----> 2 from pycaret.classification import setup, compare_models, tune_model, blend_models, save_model, load_model, predict_model
#       3 from pycaret.datasets import get_data
#       4
#       5 # Load sample dataset
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)     86     "check_drift",
#      87 ]
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\classification\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\classification\oop.py:17
#      14 from scipy.optimize import shgo
#      16 from pycaret.containers.metrics.classification import get_all_metric_containers
# ---> 17 from pycaret.containers.models.classification import (
#      18     ALL_ALLOWED_ENGINES,
#      19     get_all_model_containers,
#      20     get_container_default_engines,
#      21 )
#      22 from pycaret.internal.display import CommonDisplay
#      23 from pycaret.internal.logging import get_logger
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\containers\models\classification.py:19
#      17 import pycaret.containers.base_container
#      18 import pycaret.internal.cuml_wrappers
# ---> 19 from pycaret.containers.models.base_model import (
#      20     ModelContainer,
#      21     leftover_parameters_to_categorical_distributions,
#      22 )
#      23 from pycaret.internal.cuml_wrappers import get_svc_classifier
#      24 from pycaret.internal.distributions import (
#      25     Distribution,
#      26     IntUniformDistribution,
#      27     UniformDistribution,
#      28 )
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\containers\models\base_model.py:9
#       7 from pycaret.containers.base_container import BaseContainer
#       8 from pycaret.internal.distributions import CategoricalDistribution
# ----> 9 from pycaret.internal.pycaret_experiment.pycaret_experiment import _PyCaretExperiment
#      10 from pycaret.utils.generic import get_allowed_engines, get_logger
#      13 class ModelContainer(BaseContainer):
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:10
#       7 import cloudpickle
#       8 import pandas as pd
# ---> 10 import pycaret.internal.patches.sklearn
#      11 import pycaret.internal.patches.yellowbrick
#      12 import pycaret.internal.persistence
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\internal\patches\sklearn.py:9
#       6 from sklearn.model_selection._validation import _fit_and_score, _score
#       7 from sklearn.utils import check_random_state
# ----> 9 from pycaret.internal.pipeline import pipeline_predict_inverse_only
#      11 # Monkey patching sklearn.model_selection._search to avoid overflows on windows.
#      12
#      13
#      14 # adapted from https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/utils/_random.pyx
#      15 def _mp_sample_without_replacement(
#      16     n_population: int, n_samples: int, method=None, random_state=None
#      17 ) -> Any:
#
# File ~\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\pycaret\internal\pipeline.py:19
#      17 import sklearn.pipeline
#      18 from sklearn.base import clone
# ---> 19 from sklearn.utils import _print_elapsed_time
#      20 from sklearn.utils.metadata_routing import _routing_enabled
#      21 from sklearn.utils.metaestimators import available_if
#
# ImportError: cannot import name '_print_elapsed_time' from 'sklearn.utils' (C:\Users\esmae\Documents\Educx Kurs machine lerning\aufgabe\.venv\Lib\site-packages\sklearn\utils\__init__.py)
